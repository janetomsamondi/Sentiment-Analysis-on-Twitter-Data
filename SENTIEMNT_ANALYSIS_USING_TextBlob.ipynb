# %% [markdown]
# I will perform basic sentiment analysis on collected COVID19-related Twitter data, using the TextBlob entiment analysis tool.
# This tool uses a lexicon (i.e. a dictionary/vocabulary of words and their respective sentiment scores) and rule-based approach to classify text as either negative, neutral or positive.
# However, the fact that sentiment is calculated based on the polarity score of each word in the text can lead to errors in sentiment classification. Such errors may arise due to a lack of understanding of various language traits such as sarcasm or even variations in the use of word the same word.

# %%
import pandas as pd
import csv
import re
import numpy as np
import plotly.express as px
from plotly.offline import init_notebook_mode
# !pip install vaderSentiment

from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 6.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %% [markdown]
# We now read in our Twitter data that has been partially cleaned and put it into a pandas dataframe.

# %%
# Read in the data and put it into a dataframe
df = pd.read_csv("/content/Datafram_CSV.csv")

# Have a quick look at the dataframe
df
# Out:
#      Unnamed: 0         tweet_id_str            date_time        location  \
# 0             0  1529612798241959943  2022-05-25 23:58:04           Kenya
# 1             1  1529612784828305408  2022-05-25 23:58:01             NaN
# 2             2  1529611298098618368  2022-05-25 23:52:06        Ethiopia
# 3             3  1529610794933305345  2022-05-25 23:50:06           Kenya
# 4             4  1529609511404818433  2022-05-25 23:45:00        Ethiopia
# ..          ...                  ...                  ...             ...
# 995         995  1529321937398386693  2022-05-25 04:42:17           Kenya
# 996         996  1529321879781003264  2022-05-25 04:42:04           Kenya
# 997         997  1529320692038176768  2022-05-25 04:37:21           Kenya
# 998         998  1529320434805645319  2022-05-25 04:36:19  Eldoret, Kenya
# 999         999  1529320428627447808  2022-05-25 04:36:18           Kenya
#
#                                             tweet_text
# 0    Water melon for Ksh18.00 @ kg in Bura tana. Dm...
# 1    true democracy is practised in china, people h...
# 2    The Amhara regional state government has engag...
# 3    pigs for Ksh6,000.00 @ piglet in Nakuru. high ...
# 4    ‘Amhara security forces launched a campaign to...
# ..                                                 ...
# 995  Kenya Kwanza fringe parties protest UDA's six-...
# 996  onions for Ksh40.00 @ kg in Karatina. \nOrder ...
# 997  Kenya needs an economy recovery plan. We need ...
# 998  A diligent, honest and transparent leader who ...
# 999  How we tell narratives about Africa matters. T...
#
# [1000 rows x 5 columns]

# %%
#Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

#Create a function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %% [markdown]
# Let's try out these TextBlob tools by entering any text you'd like - try different examples, i.e. text which you think has positive or negative sentiment and see if TextBlob can get it right! Does punctuation make a difference? How does it handle sarcasm or common text slang such as 'lol'?

# %%
your_text = 'this is so cool'
getPolarity(your_text), getSubjectivity(your_text)
# Out:
# (0.35, 0.65)

# %%
df['subjectivity'] = df['tweet_text'].apply(getSubjectivity)
df['polarity'] = df['tweet_text'].apply(getPolarity)

df
# Out:
#      Unnamed: 0         tweet_id_str            date_time        location  \
# 0             0  1529612798241959943  2022-05-25 23:58:04           Kenya
# 1             1  1529612784828305408  2022-05-25 23:58:01             NaN
# 2             2  1529611298098618368  2022-05-25 23:52:06        Ethiopia
# 3             3  1529610794933305345  2022-05-25 23:50:06           Kenya
# 4             4  1529609511404818433  2022-05-25 23:45:00        Ethiopia
# ..          ...                  ...                  ...             ...
# 995         995  1529321937398386693  2022-05-25 04:42:17           Kenya
# 996         996  1529321879781003264  2022-05-25 04:42:04           Kenya
# 997         997  1529320692038176768  2022-05-25 04:37:21           Kenya
# 998         998  1529320434805645319  2022-05-25 04:36:19  Eldoret, Kenya
# 999         999  1529320428627447808  2022-05-25 04:36:18           Kenya
#
#                                             tweet_text  subjectivity  polarity
# 0    Water melon for Ksh18.00 @ kg in Bura tana. Dm...      0.500000  0.500000
# 1    true democracy is practised in china, people h...      0.330556  0.133333
# 2    The Amhara regional state government has engag...      0.000000  0.000000
# 3    pigs for Ksh6,000.00 @ piglet in Nakuru. high ...      0.520000  0.330000
# 4    ‘Amhara security forces launched a campaign to...      0.000000 -0.100000
# ..                                                 ...           ...       ...
# 995  Kenya Kwanza fringe parties protest UDA's six-...      0.000000  0.000000
# 996  onions for Ksh40.00 @ kg in Karatina. \nOrder ...      0.000000  0.000000
# 997  Kenya needs an economy recovery plan. We need ...      0.300000  1.000000
# 998  A diligent, honest and transparent leader who ...      0.550000  0.400000
# 999  How we tell narratives about Africa matters. T...      0.430000  0.380000
#
# [1000 rows x 7 columns]

# %% [markdown]
# Next, let's create a function to add a sentiment label to each tweet, based on it's polarity score.

# %%
# Create a function to label postitive, neutral and negative tweets

def get_sentiment_label(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
# Apply the get_sentiment_label function to the polarity column
# and add the sentiment results as a new column in our dataframe

df['TBsentiment'] = df['polarity'].apply(get_sentiment_label)
df
# Out:
#      Unnamed: 0         tweet_id_str            date_time        location  \
# 0             0  1529612798241959943  2022-05-25 23:58:04           Kenya
# 1             1  1529612784828305408  2022-05-25 23:58:01             NaN
# 2             2  1529611298098618368  2022-05-25 23:52:06        Ethiopia
# 3             3  1529610794933305345  2022-05-25 23:50:06           Kenya
# 4             4  1529609511404818433  2022-05-25 23:45:00        Ethiopia
# ..          ...                  ...                  ...             ...
# 995         995  1529321937398386693  2022-05-25 04:42:17           Kenya
# 996         996  1529321879781003264  2022-05-25 04:42:04           Kenya
# 997         997  1529320692038176768  2022-05-25 04:37:21           Kenya
# 998         998  1529320434805645319  2022-05-25 04:36:19  Eldoret, Kenya
# 999         999  1529320428627447808  2022-05-25 04:36:18           Kenya
#
#                                             tweet_text  subjectivity  \
# 0    Water melon for Ksh18.00 @ kg in Bura tana. Dm...      0.500000
# 1    true democracy is practised in china, people h...      0.330556
# 2    The Amhara regional state government has engag...      0.000000
# 3    pigs for Ksh6,000.00 @ piglet in Nakuru. high ...      0.520000
# 4    ‘Amhara security forces launched a campaign to...      0.000000
# ..                                                 ...           ...
# 995  Kenya Kwanza fringe parties protest UDA's six-...      0.000000
# 996  onions for Ksh40.00 @ kg in Karatina. \nOrder ...      0.000000
# 997  Kenya needs an economy recovery plan. We need ...      0.300000
# 998  A diligent, honest and transparent leader who ...      0.550000
# 999  How we tell narratives about Africa matters. T...      0.430000
#
#      polarity TBsentiment
# 0    0.500000    Positive
# 1    0.133333    Positive
# 2    0.000000     Neutral
# 3    0.330000    Positive
# 4   -0.100000    Negative
# ..        ...         ...
# 995  0.000000     Neutral
# 996  0.000000     Neutral
# 997  1.000000    Positive
# 998  0.400000    Positive
# 999  0.380000    Positive
#
# [1000 rows x 8 columns]

# %% [markdown]
# We can have a quick look at the sentiment distribution of the tweets as follows:

# %%
df['TBsentiment'].value_counts()
# Out:
# Neutral     414
# Positive    393
# Negative    193
# Name: TBsentiment, dtype: int64

# %% [markdown]
# Let's have a closer look at the tweets which TexBlob has classified as the most positive and most negative, to check the accuracy of the assigned sentiment. To do this, we will first sort all the tweets by polarity in descending order, i.e. from the most positive tweets to the most negative.

# %%
#We sort the tweets by their polarity value and put the sorted tweets into a new dataframe 

sorted_df = df.sort_values(by=['polarity'], ascending=False)

# %% [markdown]
# Next, let's print out the top 15 most negative tweets, which are now the last 15 tweets in the new dataframe. Do these tweets have a negative sentiment?

# %%
#Print out the text from the last 15 tweets in the sorted dataframe

for i, tweet in enumerate(sorted_df.tail(15)['tweet_text']):
    print(i+1, tweet, '\n')
# Out:
# 1